# %% [markdown]
# <a href="https://colab.research.google.com/github/PravallikaSomisetti/Sky-Brisk/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**1. Variables**
# *Variables are used to store and manage data values in a program.*

# %%
a = 10
name = "Python"
print(a)
print(name)
# Out:
# 10
# Python

# %% [markdown]
#  # **2. Data Types**
# *Data types define the type of data a variable can hold, such as numbers, text, or boolean values.*
#
# **int –** Whole numbers (10, 20)
#
# **float –** Decimal numbers (2.5, 7.8)
#
# **str –** Text ("Hello")
#
# **bool –** True / False

# %% [markdown]
# # **3. Operators**
# *Operators are symbols used to perform operations on variables and values.*
#
# **Arithmetic:** +, -, *, /, %
#
# **Relational:** >, <, >=, <=, ==, !=
#
# **Logical:** and or not

# %% [markdown]
# # **4. Input / Output**
# **Input:** *Input is used to take data from the user during program execution.*
#
# **Output:** *Output is used to display results or messages to the user.*

# %%
name = input("Enter your name: ")
print("Hello", name, "!")
# Out:
# Enter your name: Pravallika
# Hello Pravallika !

# %% [markdown]
# # **5. Conditional Statements (if–else)**
# *Conditional statements execute different blocks of code based on given conditions.*

# %%
age = int(input("Enter your current age: "))
if age >= 18:
    print("You are eligible to vote")
else:
    print("You are Not eligible to vote")
# Out:
# Enter your current age: 20
# You are eligible to vote

# %% [markdown]
# # **6. Loops**
#
# ## for loop
# *A for loop is used to iterate over a sequence of values for a fixed number of times.*

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## while loop
# *A while loop executes a block of code repeatedly as long as a condition is true.*

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # **Hands-On Programs**
#
# **1) Temperature Converter (Celsius → Fahrenheit)**
#
# *A temperature converter converts values from one temperature scale to another.*

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 82
# Temperature in Fahrenheit: 179.6

# %% [markdown]
# **2) Simple Calculator**
#
# *A calculator program performs basic arithmetic operations like addition, subtraction, multiplication, and division.*

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Enter first number: 5
# Enter second number: 15
# Addition: 20.0
# Subtraction: -10.0
# Multiplication: 75.0
# Division: 0.3333333333333333

# %% [markdown]
# # **Client Project**
#
# ### **Average Temperature Calculator**
#
# *An average temperature script calculates the mean of multiple temperature values.*

# %%
num = int(input("Enter number of days: "))
total = 0

for i in range(num):
    temp = float(input(f"Enter temperature for day {i+1}: "))
    total += temp

average = total / num
print("Average Temperature:", average)
# Out:
# Enter number of days: 3
# Enter temperature for day 1: 55
# Enter temperature for day 2: 26
# Enter temperature for day 3: 48
# Average Temperature: 43.0
